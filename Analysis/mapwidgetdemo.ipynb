# %%
# Initialize the Earth Engine object, using the authentication credentials.
ee.Initialize()

# %%
# Import the packages you need
# %matplotlib inline

from __future__ import print_function # For py 2.7 compat

import ee
import datetime
from IPython.html import widgets
from IPython.display import display
from IPython.utils import traitlets
from IPython.core.display import Javascript

# %%
image = ee.Image('srtm90_v4')
from IPython.display import Image
Image(url=image.getThumbUrl({'min':0, 'max': 3000}))
# Out:
# <img src="https://earthengine.googleapis.com//api/thumb?thumbid=d3309596490160c51ecf1e0ef470ccf3&token=a8e4aff2276978d0f76da40207e77e4d"/>

# %%
import IPython
IPython.__version__
# Out:
# '2.0.0'

# %%
# %run 'define_google_maps_interactive_widget.ipynb'

# %%
Irene= ee.Image("users/kuhniculous/popImage")
irene_flood_img = ((Irene.select(["b1"],['flood'])).eq(160))
palette = ["22e5ef", "820bff"];
#Map.addLayer(irene_flood_img.mask(irene_flood_img), {palette: palette, min:0, max:1}, 'NY DFO Flood Image');

# %%
map = GoogleMapsWidget(lat=41.14, lng=-73.83, zoom=10) # lat, lng and zoom are optional
display(map)

map.addLayer(irene_flood_img.mask(irene_flood_img), {palette: palette, min:0, max:1}, 'NY DFO Flood Image')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e1a4b2567db8> in <module>()
#       2 display(map)
#       3
# ----> 4 map.addLayer(irene_flood_img.mask(irene_flood_img), {palette: palette, min:0, max:1}, 'NY DFO Flood Image')
#
# TypeError: unhashable type: 'list'
